# %%
import numpy as np

# %%
a = np.array([[1,2,3],[4,5,6]],dtype = np.float32)
print(a)
# Out:
# [[1. 2. 3.]
#  [4. 5. 6.]]

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\steve\anaconda3\lib\site-packages (8.2.0)

# %%
from PIL import Image

infile = 'image.jpg'
im = Image.open(infile)
#im.show()
display(im)

print(infile, im.format, "%dx%d" %  im.size, im.mode)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=626x469 at 0x1CFC6889CA0>
# image.jpg JPEG 626x469 RGB

# %%
out = im.resize((128,128))
display(out)
out = im.rotate(45) #degrees counter-clockwise
display(out)
out = im.transpose(Image.FLIP_LEFT_RIGHT)
display(out)
out = im.transpose(Image.FLIP_TOP_BOTTOM)
display(out)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CFC67FC340>
# <PIL.Image.Image image mode=RGB size=626x469 at 0x1CFC69BB130>
# <PIL.Image.Image image mode=RGB size=626x469 at 0x1CFC67F3250>
# <PIL.Image.Image image mode=RGB size=626x469 at 0x1CFC67FC340>

# %%
box = (100,100,400,400) #left,upper,right,bottom
region = im.crop(box)

display(region)
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x1CFC69A5BB0>

# %%
from PIL import Image, ImageFilter

out1 = im.filter(ImageFilter.BLUR)
display(out1)
out2 = im.filter(ImageFilter.GaussianBlur(radius=20))
display(out2)
# Out:
# <PIL.Image.Image image mode=RGB size=626x469 at 0x1CFC69A5A30>
# <PIL.Image.Image image mode=RGB size=626x469 at 0x1CFC67F3FA0>
